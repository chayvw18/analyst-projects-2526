# %% [markdown]
# <a href="https://colab.research.google.com/github/chayvw18/analyst-projects-2526/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/MyDrive/GLI-2025
# Out:
# /content/drive/MyDrive/GLI-2025

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
from scipy import stats

# %%
data = pd.read_csv('/content/drive/MyDrive/GLI-2025/employee_performance_dataset.csv')
data.head()
# Out:
#    Age  YearsExperience   Department  Education  Salary  PerformanceScore  \
# 0   50               31   Operations    Masters   87185                75
# 1   36               17   Operations  Bachelors   56858                98
# 2   29                7  Procurement    Masters   51223                51
# 3   42               20  Procurement  Bachelors   69375                74
# 4   40               18    Logistics        PhD   77302                52
#
#   Promotion  Sales  CustomerSatisfaction
# 0        No    171                     5
# 1       Yes    189                     1
# 2        No    115                     3
# 3        No    159                     3
# 4        No    248                     3

# %%
sns.barplot(data= data,  y='Department', x='Salary')
# Out:
# <Axes: xlabel='Salary', ylabel='Department'>
